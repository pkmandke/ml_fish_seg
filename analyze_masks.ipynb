# %%
import nibabel as nib
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
i = cv2.imread('./50segmentations/INHS_FISH_066.jpg')
j = nib.load('./50segmentations/INHS_FISH_066_seg.nii')

# %%
j = np.asarray(j.dataobj)

# %%
i.shape, j.shape
# Out:
# ((4016, 6016, 3), (5488, 2751, 1))

# %%
plt.imshow(cv2.resize(i, (512, 512)))

# %%
plt.imshow(cv2.resize(j[:, :, 0].T, (512, 512)))

# %%
plt.imshow(cv2.resize(i, (512, 512), cv2.INTER_LINEAR) + 8*np.repeat(cv2.resize(j[:, :, 0].T, (512, 512), cv2.INTER_NEAREST).reshape(512, 512, 1), 3, axis=2))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
